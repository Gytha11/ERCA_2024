# %% [markdown]
# # ERCA 2024 mini-paper group 5: Snow?

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
path_to_data = r'Data/data_monthly_DE_DWD.csv'
# read data
snow_data = pd.read_csv(path_to_data)
# snow depth (HS), depth of snowfall (HN, also denoted as fresh snow or snowfall), 
# snow water equivalent (SWE), snow cover area (SCA), and snow cover duration (SCD)

# %%
snow_data
# Out:
#               Name  year  month  HNsum    HSmean  HSmax  SCD1  SCD1gt  SCD10  \
# 0             Aach  1937      1    NaN  0.161290    5.0   1.0     1.0    0.0
# 1             Aach  1937      2    NaN  0.857143   10.0   5.0     5.0    1.0
# 2             Aach  1937      3    NaN  0.000000    0.0   0.0     0.0    0.0
# 3             Aach  1937      4    NaN  0.000000    0.0   0.0     0.0    0.0
# 4             Aach  1937      5    NaN  0.000000    0.0   0.0     0.0    0.0
# ...            ...   ...    ...    ...       ...    ...   ...     ...    ...
# 532747  Zwiefalten  2008      8    NaN       NaN    NaN   NaN     NaN    NaN
# 532748  Zwiefalten  2008      9    NaN       NaN    NaN   NaN     NaN    NaN
# 532749  Zwiefalten  2008     10    NaN       NaN    NaN   NaN     NaN    NaN
# 532750  Zwiefalten  2008     11    NaN       NaN    NaN   NaN     NaN    NaN
# 532751  Zwiefalten  2008     12    NaN       NaN    NaN   NaN     NaN    NaN
#
#         SCD20  ...  HSmean_gapfill  frac_gapfilled  HSmax_gapfill  \
# 0         0.0  ...             NaN             NaN            NaN
# 1         0.0  ...             NaN             NaN            NaN
# 2         0.0  ...             NaN             NaN            NaN
# 3         0.0  ...             NaN             NaN            NaN
# 4         0.0  ...             NaN             NaN            NaN
# ...       ...  ...             ...             ...            ...
# 532747    NaN  ...        0.000000             1.0            0.0
# 532748    NaN  ...        0.000000             1.0            0.0
# 532749    NaN  ...        0.000000             1.0            0.0
# 532750    NaN  ...        1.066667             1.0            9.0
# 532751    NaN  ...        3.645161             1.0           14.0
#
#         SCD1_gapfill  SCD1gt_gapfill  SCD10_gapfill  SCD20_gapfill  \
# 0                NaN             NaN            NaN            NaN
# 1                NaN             NaN            NaN            NaN
# 2                NaN             NaN            NaN            NaN
# 3                NaN             NaN            NaN            NaN
# 4                NaN             NaN            NaN            NaN
# ...              ...             ...            ...            ...
# 532747           0.0             0.0            0.0            0.0
# 532748           0.0             0.0            0.0            0.0
# 532749           0.0             0.0            0.0            0.0
# 532750           9.0             7.0            0.0            0.0
# 532751          19.0            12.0            6.0            0.0
#
#         SCD30_gapfill  SCD50_gapfill  SCD100_gapfill
# 0                 NaN            NaN             NaN
# 1                 NaN            NaN             NaN
# 2                 NaN            NaN             NaN
# 3                 NaN            NaN             NaN
# 4                 NaN            NaN             NaN
# ...               ...            ...             ...
# 532747            0.0            0.0             0.0
# 532748            0.0            0.0             0.0
# 532749            0.0            0.0             0.0
# 532750            0.0            0.0             0.0
# 532751            0.0            0.0             0.0
#
# [532752 rows x 23 columns]
