# %% [markdown]
# # ERCA 2024 mini-paper group 5: Snow?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Introduction
# How has snow depth and snow fall evolved in differnet

# %%
path_to_data = r'Data/data_monthly_DE_DWD.csv'
# read data
snow_data = pd.read_csv(path_to_data, parse_dates={"date": ["year", "month"]})
# snow depth (HS), depth of snowfall (HN, also denoted as fresh snow or snowfall), 
# snow water equivalent (SWE), snow cover area (SCA), and snow cover duration (SCD)
# look at Bondorf, Hohenpreissenberg and Zugspitze and Unterammergau

# %%
#snow_data.Name.unique()
snow_data.columns
# Out:
# Index(['date', 'Name', 'HNsum', 'HSmean', 'HSmax', 'SCD1', 'SCD1gt', 'SCD10',
#        'SCD20', 'SCD30', 'SCD50', 'SCD100', 'HSmean_gapfill', 'frac_gapfilled',
#        'HSmax_gapfill', 'SCD1_gapfill', 'SCD1gt_gapfill', 'SCD10_gapfill',
#        'SCD20_gapfill', 'SCD30_gapfill', 'SCD50_gapfill', 'SCD100_gapfill'],
#       dtype='object')

# %%
#plot snowdwepth for choosen stations in one plot
li_stations = ["Bondorf", "Hohenpeissenberg", "Zugspitze", "Unterammergau"]
fig, ax = plt.subplots(4,1, sharex = True, figsize = (10,6))

for i, name in enumerate(li_stations):
    data = snow_data.where(snow_data['Name'] == name)
    ax[i].plot(data.date, data["HSmean_gapfill"], linewidth = 1, label = name) #marker = "o", 
    ax[i].legend(loc = "upper left")
    ax[i].set_ylabel("snow depth [cm]")
    ax[i].grid()
ax[3].set_xlabel("year")
fig.suptitle('Snowdepth')
# Out:
# Text(0.5, 0.98, 'Snowdepth')
