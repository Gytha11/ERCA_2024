# %% [markdown]
# # ERCA 2024 mini-paper group 5: Snow?

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %% [markdown]
# ## Introduction
# How has snow depth and snow fall evolved in differnent towns in Germany?

# %%
path_to_data = r'Data/data_monthly_DE_DWD.csv'
# read data
snow_data = pd.read_csv(path_to_data)
# snow depth (HS), depth of snowfall (HN, also denoted as fresh snow or snowfall), 
# snow water equivalent (SWE), snow cover area (SCA), and snow cover duration (SCD)
# look at Bondorf, Hohenpreissenberg and Zugspitze and Unterammergau

# %%
snow_data.Name.unique()
# Out:
# array(['Aach', 'Aalen_Unterkochen', 'Aalen_Unterrombach',
#        'Abbach_Bad_Dunzling', 'Abensberg_Sandharlanden',
#        'Abtsgmund_Neubronn', 'Abtsgmund_Untergroningen',
#        'Achberg_Doberatsweiler', 'Achern_Fautenbach', 'Adelmannsfelden',
#        'Affing', 'Aholfing', 'Aibling_Bad_Ellmosen', 'Aichstetten',
#        'Aiglsbach', 'Aislingen', 'Aiterhofen', 'Aitern_Untermulten',
#        'Aitrang', 'Albaching', 'Albstadt_Badkap', 'Albstadt_Burgfelden',
#        'Albstadt_Ebingen', 'Albstadt_Onstmettingen',
#        'Aldersbach_Kriestorf', 'Alfdorf_Pfahlbronn',
#        'Alpirsbach_Klaranlage_', 'Altensteig_Wart',
#        'Altheim_Kreis_Biberach', 'Althengstett_Ottenbronn',
#        'Altmannstein_Laimerstadt', 'Altmannstein_Pondorf',
#        'Altomunster_Maisbrunn', 'Altomunster_Wollomoos',
#        'Altusried_Krugzell', 'Altusried_Muthmannshofen', 'Amerang_Kammer',
#        'Amerang_Pfaffing', 'Amerdingen', 'Andechs_Erling',
#        'Anger_Oberhogl', 'Anger_Stoissberg', 'Apfeldorf', 'Arnstorf',
#        'Aschau_Innerkoy', 'Aschau_Sachrang', 'Aschau_Stein',
#        'Aspach_Allmersbach_am_Weinberg', 'Attenkam', 'Au_am_Rhein',
#        'Au_i_d_Hallertau_Gunzenhausen', 'Auerberg', 'Aufkirchen',
#        'Augsburg', 'Augsburg_Hochablass_', 'Augsburg_Sankt_Stephan_',
#        'Aulendorf_Haslach', 'Aying_Kleinhelfendorf', 'Babenhausen',
#        'Backnang', 'Bad_Birnbach', 'Baden_Baden_Geroldsau', 'Baierbach',
#        'Baiern_Kleinrohrsdorf', 'Baiersbronn_Mitteltal',
#        'Baiersbronn_Obertal', 'Baiersbronn_Ruhestein',
#        'Baiersbronn_Schonegrund', 'Baiersbronn_Zwickgabel', 'Baindt',
#        'Balderschwang', 'Balgheim', 'Balingen_Heselwangen',
#        'Baltmannsweiler_Hohengehren', 'Bartholoma', 'Bayerbach_Holskofen',
#        'Bayersoien_Bad', 'Bayrischzell', 'Benediktbeuern',
#        'Berchtesgaden_KKst_', 'Berchtesgaden_Obersalzberg',
#        'Berchtesgaden_Unterau', 'Berglen_Birkenweissbuch', 'Berkheim',
#        'Bernau_Goldbach', 'Bernau_Kreis_Rosenheim', 'Bernbeuren',
#        'Bernbeuren_Prachtsried', 'Bernried_Niederbayern_Buchet',
#        'Biberbach_Markt', 'Bingen_Kreis_Sigmaringen', 'Bischofsmais',
#        'Bischofswiesen_Engedey', 'Bischofswiesen_Loipl',
#        'Bischofswiesen_Winkl', 'Bissingen_Klaranlage_', 'Bitz',
#        'Blaubeuren_Wennenden', 'Blaustein_Bermaringen', 'Blindheim',
#        'Blumberg', 'Bobing', 'Bobingen', 'Boblingen',
#        'Bockhorn_Oberbayern_Grunbach', 'Bodenkirchen_Aich',
#        'Bodman_Ludwigshafen', 'Bodnegg_Billen', 'Bogen_Pfelling',
#        'Bohming', 'Boll_Bad', 'Bondorf',
#        'Bonndorf_Schwarzwald_Martinstr_', 'Boos', 'Bopfingen_Baldern',
#        'Bopfingen_Flochberg', 'Bottingen', 'Brannenburg_Degerndorf',
#        'Breisach', 'Breitenbrunn_Furbuch', 'Breitingen', 'Breitnau',
#        'Bruckberg_Niederbayern_Porndorf', 'Brunnsteinhaus', 'Buchau_Bad',
#        'Buchenbach', 'Buchenberg', 'Buchenberg_Kreuzthal',
#        'Buchlberg_Kammerwetzdorf', 'Buchlberg_Tannod', 'Buchloe',
#        'Buhlertal', 'Buhlertal_Obertal', 'Burchau', 'Burgau',
#        'Burgkirchen_Gendorf', 'Burgkirchen_Schonberg', 'Burladingen',
#        'Chieming', 'Chieming_Chiemsee', 'Chiemsee_Herrenchiemsee',
#        'Dachau', 'Dachsberg_Wolpadingen', 'Dasing_Klaranlage_',
#        'Deckenpfronn', 'Deggendorf', 'Deggenhausertal_Azenweiler',
#        'Deisenhofen_Kreis_Munchen', 'Denkendorf', 'Denklingen_Dienhausen',
#        'Denzlingen', 'Diedorf_Schwaben_Biburg',
#        'Diessen_Ammersee_Riederau', 'Dietersburg', 'Dillingen_Donau',
#        'Dillingen_Donau_Fristingen', 'Dinkelscherben',
#        'Dischingen_Egauwasserwerk_', 'Dischingen_Eglingen',
#        'Ditzenbach_Bad', 'Ditzingen_Heimerdingen', 'Dobel',
#        'Donaueschingen', 'Donauworth', 'Dorfen_Klaranlage_',
#        'Dornstetten', 'Dornstetten_Aach', 'Durach_Bodelsberg',
#        'Durbach_Ebersweier', 'Durrheim_Bad', 'Eberfing', 'Ebersbach_Fils',
#        'Ebersberg_Halbing', 'Efringen_Kirchen_Kleinkems', 'Egenhofen',
#        'Eggenfelden', 'Eggenthal_Grub', 'Egglham',
#        'Eging_am_See_Burgstall', 'Egling_Isar_Attenham', 'Ehingen_Donau',
#        'Ehingen_Donau_Frankenhofen', 'Ehingen_Kirchen',
#        'Ehingen_a_Ries_Schaffhauser_Hof_', 'Ehningen', 'Eiberg',
#        'Eichendorf', 'Eichstatt_Landershofen', 'Eichstetten',
#        'Eimeldingen', 'Eisenbach', 'Eitting', 'Ellgau',
#        'Ellwangen_Rindelbach', 'Elzach_Fisnacht', 'Elzach_Oberprechtal',
#        'Emmendingen_Mundingen', 'Emmingen_Liptingen', 'Endorf_Bad',
#        'Engen_Hegau', 'Engen_Stetten', 'Eningen', 'Epfendorf_Butschhof',
#        'Eppishausen_Haselbach', 'Erbach_Ringingen', 'Erdweg',
#        'Eresing_Sankt_Ottilien_', 'Ergolding_Pfarrkofen',
#        'Ergoldsbach_Klaham', 'Ering', 'Eriskirch_Mariabrunn', 'Erstetten',
#        'Eschbach', 'Eschbronn_Mariazell', 'Eschenlohe', 'Essenbach',
#        'Esslingen_Neckar', 'Ettal', 'Ettal_Graswang',
#        'Ettenheim_Ettenheimmunster', 'Ettlingen_Ettlingenweier',
#        'Eurasburg_Freienried', 'Eurasburg_Oberbayern_Quarzbichl',
#        'Fahrenzhausen', 'Falkenberg_Kr_Rottal_Inn', 'Feilnbach_Bad',
#        'Feldberg_Schwarzwald', 'Feldkirchen_Westerham_Lenzmuhle',
#        'Feldkirchen_Westerham_Vagen', 'Fellbach',
#        'Finningen_Brunnenmuhle_', 'Finsing_Kraftwerk_',
#        'Fischbachau_Birkenstein', 'Fischbachau_Schreiern', 'Fischen',
#        'Fischhausen_bei_Schliersee', 'Flintsbach_Inn_Asten',
#        'Fluorn_Winzeln', 'Forbach_Herrenwies', 'Forstinning', 'Frasdorf',
#        'Frauenau', 'Frauenneuharting_Lohen', 'Freiamt_Keppenbach',
#        'Freiamt_Ottoschwanden', 'Freiburg', 'Freiburg_im_Breisgau_Ebnet',
#        'Freiburg_im_Breisgau_Haslach', 'Freiburg_im_Breisgau_Herdern',
#        'Freiburg_im_Breisgau_Mooswald',
#        'Freiburg_im_Breisgau_Sankt_Georgen',
#        'Freiburg_im_Breisgau_Schlierberg', 'Freilassing', 'Fremdingen',
#        'Freudenstadt', 'Freudenstadt_Igelsberg', 'Freudenstadt_Kniebis',
#        'Freudenstadt_Kurgarten', 'Freyung_Kreuzberg', 'Frickenhofen',
#        'Fridingen', 'Fridolfing', 'Friedrichshafen',
#        'Fronreute_Blitzenreute', 'Furstenzell',
#        'Furstenzell_Hohenstadt_Bad', 'Furtwangen', 'Fussen_Weissensee',
#        'Fussing_Bad_Voglod', 'Gablingen_Lutzelburg',
#        'Gaggenau_Rotenfels_Bad', 'Gaimersheim', 'Gangkofen_Klaranlage_',
#        'Garmisch_Partenkirchen', 'Garmisch_Partenkirchen_Eckbauer',
#        'Garmisch_Partenkirchen_Kaltenbrunn',
#        'Garmisch_Partenkirchen_Kreuzeckhaus_', 'Geiselhoring',
#        'Geiselhoring_Ponning', 'Geisenfeld_Eichelberg', 'Geisenhausen',
#        'Geisingen', 'Geislingen_an_der_Steige', 'Gelbelsee', 'Geretsried',
#        'Gerstetten', 'Gerstetten_Dettingen', 'Gersthofen',
#        'Gessertshausen_Wollishausen', 'Gilching', 'Glottertal',
#        'Goggingen', 'Gomadingen', 'Goppingen_Hohenstaufen',
#        'Goppingen_Jebenhausen', 'Gorisried', 'Gorwihl_Segeten',
#        'Gottmadingen', 'Grafenhausen_Hochschwarzwald', 'Grafling',
#        'Grafling_Muhlen', 'Grafrath_Unteralting', 'Grainau',
#        'Grainau_Eibsee', 'Grainet_Rehberg', 'Grassau',
#        'Griesbach_Bad_im_Rottal_Kemading', 'Grobenzell',
#        'Gronenbach_Thal', 'Grossmehring_Theissing', 'Gruibingen',
#        'Gschwend_Kr_Ostalb', 'Gundelfingen_Donau_Petersworth', 'Gunzburg',
#        'Gutach_im_Breisgau_Bleibach', 'Haag_Kreis_Muhldorf', 'Hagelstadt',
#        'Haidmuhle_Bischofsreut', 'Haigerloch_Weildorf',
#        'Haimhausen_Ottershausen', 'Haiming', 'Haiterbach',
#        'Halblech_Trauchgau', 'Hallbergmoos_Goldach', 'Harburg',
#        'Harthausen_Kreis_Zollernalb', 'Hartheim_am_Rhein',
#        'Haslach_im_Kinzigtal', 'Hausham_Grub', 'Hausstein', 'Hayingen',
#        'Hechingen', 'Heidenheim_Brenz', 'Heidenheim_Hohentrudingen',
#        'Heiligenberg', 'Heimenkirch', 'Heitersheim',
#        'Heldenstein_Weidenbach', 'Hengersberg',
#        'Hengersberg_Unterfrohnstetten', 'Herbolzheim_Wagenstadt',
#        'Herdwangen_Schonach', 'Herrenberg', 'Hettenshausen',
#        'Heubach_Ostalb', 'Hildrizhausen', 'Hilgertshausen_Tandern',
#        'Hindelang_Hinterstein', 'Hindelang_Oberdorf_Bad',
#        'Hindelang_Oberes_Ostrachtal_', 'Hindelang_Oberjoch',
#        'Hindelang_Unterjoch_LfW_', 'Hintersee_DE_DWD',
#        'Hitzhofen_Hofstetten', 'Hochdorf_Unteressendorf', 'Hohenbrunn',
#        'Hohenfels_Kr_Konstanz_Kalkofen', 'Hohenkammer',
#        'Hohenpeissenberg', 'Hohenstein_Bernloch', 'Hohenthann',
#        'Hollenbach_Bayern_Schonbach', 'Holzkirchen',
#        'Holzkirchen_Oberbayern_Leithen', 'Horb', 'Horb_Betra', 'Horben',
#        'Horgenzell_Happenweiler', 'Hornisgrinde', 'Hufingen_Furstenberg',
#        'Huisheim', 'Hunderdorf_Thananger', 'Huttisheim',
#        'Ichenhausen_Autenried', 'Icking', 'Ihringen', 'Illertissen',
#        'Immenstaad', 'Immenstadt', 'Immenstadt_Reute',
#        'Immenstadt_Warterhaus_', 'Ingenried_Oberbayern_Krottenhill',
#        'Ingolstadt_Flussmeisterstelle_', 'Inzell', 'Irschenberg_Kasthub',
#        'Isen_Westach', 'Isny', 'Isny_Bolsternang', 'Jachenau',
#        'Jachenau_Niedernach', 'Jedesheim', 'Jettenbach',
#        'Kaisersbach_Cronhutte', 'Kaisheim_Neuhof', 'Kaltenbronn',
#        'Kandel_Schwarzwald', 'Kandern_Sitzenkirch', 'Karlshuld',
#        'Karlsruhe_Hohenwettersbach', 'Karlsruhe_Wolfartsweier',
#        'Kaufbeuren', 'Kaufering', 'Kehl_Odelshofen',
#        'Kelheim_Kanalschleuse_', 'Kelheim_Thaldorf',
#        'Keltern_Ellmendingen', 'Kempten', 'Kiefersfelden_Gach',
#        'Kipfenberg', 'Kirchberg_Niederbayern_Zell', 'Kirchdorf_im_Wald',
#        'Kirchheim_Teck', 'Kirchweidach', 'Kisslegg', 'Klettgau_Griessen',
#        'Klippeneck', 'Kochel', 'Kochel_Einsiedl_Kraftwerk_',
#        'Kochel_Urfeld', 'Kochel_Walchenseekraftwerk_', 'Kohlgrub_Bad_A_',
#        'Kohlgrub_Bad_Rosshof_', 'Konigsbach_Stein',
#        'Konigsmoos_Ludwigsmoos', 'Konigsmoos_Untermaxfeld', 'Konstanz',
#        'Kosching', 'Kraftisried', 'Kraiburg_am_Inn', 'Krailling',
#        'Krauchenwies', 'Kressbronn', 'Kreuth_A_', 'Kreuth_Glashutte',
#        'Kronburg', 'Kroning_Leisteneck', 'Krozingen_Bad_Hausen',
#        'Krumbach_Edenhausen', 'Krun', 'Kumhausen', 'Lahr', 'Lalling',
#        'Landau_Isar', 'Landsberg_Lech', 'Landshut', 'Landshut_Schonbrunn',
#        'Langenaltheim_Buttelbronn', 'Langenargen_Oberdorf', 'Langenbach',
#        'Langenenslingen_Ittenhausen', 'Langenneufnach_Unterrothan',
#        'Langerringen_Schwabmuhlhausen', 'Langquaid',
#        'Lauben_Unterallgau_Frickenhausen',
#        'Laufen_Obb_Lebenau_Haftanstalt_', 'Lechbruck', 'Legau',
#        'Leiblfing', 'Leinau', 'Lenggries', 'Lenggries_Fall',
#        'Lenggries_Rissbachwehr_', 'Lenggries_Vorderriss',
#        'Lenningen_Schopfloch', 'Lenzkirch_Ruhbuhl', 'Leonberg_Hofingen',
#        'Leutenbach_Weiler_zum_Stein', 'Leutkirch', 'Liebenzell_Bad_LUBW_',
#        'Liliental', 'Lindau_Bodensee_', 'Lindenberg_Allgau', 'Locherberg',
#        'Loffingen_Dittishausen', 'Loiching', 'Lonsee_Ettlenschiess',
#        'Lorch_Kreis_Ostalb_Waldhausen', 'Lossburg', 'Lottstetten_Nack',
#        'Maierhofen', 'Mainburg', 'Maisach_Gernlinden', 'Maisach_Rottbach',
#        'Mallersdorf_Pfaffenberg_Niederbayern',
#        'Malsburg_Marzell_Friedrichsheim', 'Malsch_Volkersbach',
#        'Mamming_Schneiderberg', 'Mariaposching', 'Markdorf',
#        'Markgroningen', 'Marklkofen_Betriebsstelle_Vilstalsee_',
#        'Markt_Wald', 'Marktoberdorf', 'Marktoberdorf_Sulzschneid',
#        'Marktschellenberg', 'Marktschellenberg_Ettenberg',
#        'Marxzell_Schielberg', 'Mauth', 'Mauth_Finsterau', 'Meersburg',
#        'Megesheim', 'Mehring_Kr_Altotting_Niederholz', 'Memmingen',
#        'Mengen_Ennetach', 'Mengkofen_Hofdorf', 'Mengkofen_Puchhausen',
#        'Mering_Bauhof_', 'Merklingen', 'Mertingen', 'Messkirch_Rohrdorf',
#        'Messstetten_Appental', 'Messstetten_Tieringen', 'Metten',
#        'Metzingen', 'Mindelheim', 'Mindelstetten', 'Mittbach',
#        'Mittelstetten', 'Mittenwald_Buckelwiesen', 'Monheim',
#        'Monheim_Itzing', 'Moorenweis_Grunertshofen',
#        'Moosburg_Isar_Pfrombach', 'Mottingen', 'Muhlacker',
#        'Muhlacker_Grossglattbach', 'Muhlacker_Schulstr_', 'Muhldorf',
#        'Mullheim_DE_DWD', 'Munchen_Bogenhausen', 'Munchen_Flughafen',
#        'Munchen_Harlaching', 'Munchen_Kirchtrudering',
#        'Munchen_Nymphenburg', 'Munchen_Obermenzing', 'Munchen_Perlach',
#        'Munchen_Riem', 'Munchen_Sankt_Bonifaz_', 'Munchen_Stadt',
#        'Munsingen_Apfelstetten', 'Munsterhausen', 'Munstertal', 'Murnau',
#        'Murrhardt', 'Nagold', 'Nandlstadt', 'Nassenfels',
#        'Nattheim_Fleinheim', 'Neckartenzlingen', 'Nehren', 'Neidlingen',
#        'Neresheim_Stetten', 'Nersingen_Oberfahlheim',
#        'Nesseltal_bei_Bayrischzell', 'Nesselwang', 'Neu_Ulm',
#        'Neu_Ulm_Hausen', 'Neubulach_Oberhaugstett', 'Neuburg_Donau',
#        'Neuburg_Kammel_Langenhaslach', 'Neuenburg', 'Neufahrn', 'Neuffen',
#        'Neuhausen_ob_Eck', 'Neuhausen_ob_Eck_Unterschwandorf',
#        'Neumarkt_Sankt_Veit_Klaranlage_', 'Neureichenau_Duschlberg',
#        'Neureichenau_Klafferstrass', 'Neuried_Altenheim', 'Neusass',
#        'Neuschonau_Altschonau', 'Neustadt_Donau_Hienheim',
#        'Neuweiler_Kreis_Calw', 'Niederstotzingen', 'Nordrach_Barhag',
#        'Nordrach_Baumlisberg', 'Nufringen', 'Nurtingen', 'Oberau',
#        'Oberbergkirchen_Schorging', 'Obere_Firstalm_Schlierseer_Berge',
#        'Oberhaching_Laufzorn', 'Oberharmersbach',
#        'Oberhausen_Donau_Sinning', 'Oberkirch', 'Oberkochen',
#        'Oberndorf_Neckar', 'Oberndorf_Neckar_Aistaig', 'Obernzell',
#        'Oberpframmern', 'Oberreichenbach', 'Oberreute', 'Oberried_Baden',
#        'Oberried_Hofsgrund', 'Oberried_Sankt_Wilhelm',
#        'Oberried_Sankt_Wilhelm_Forsthaus_', 'Oberried_Zastler',
#        'Oberschleissheim', 'Obersochering_Reinthal',
#        'Oberstaufen_Steibis', 'Oberstaufen_Thalkirchdorf', 'Oberstdorf',
#        'Oberstdorf_Birgsau', 'Obertaufkirchen', 'Obing_Ilzham',
#        'Ochsenhausen', 'Ochsenhausen_Mittelbuch', 'Offenburg', 'Ohlsbach',
#        'Ohlstadt_Schwaiganger', 'Opfenbach', 'Oppenau', 'Ortenburg',
#        'Osterhofen', 'Osterhofen_Thundorf', 'Osterzell', 'Otterfing',
#        'Ottobeuren', 'Otzing', 'Owingen', 'Oy_Mittelberg',
#        'Oy_Mittelberg_Petersthal', 'Palling_Lampertsham',
#        'Passau_Maierhof', 'Passau_Oberhaus', 'Peiting_Herzogsagmuhle',
#        'Pentling_Matting', 'Petersdorf_Schonleiten',
#        'Pfarrkirchen_DE_DWD', 'Pfeffenhausen_Ludmannsdorf',
#        'Pforzen_Ingenried_Allgau', 'Pforzheim_Eutingen',
#        'Pforzheim_Ispringen', 'Pfronten_Rehbichel', 'Pfullendorf',
#        'Philippsreut', 'Pilsting_Backermuhle', 'Pleidelsheim',
#        'Plochingen', 'Pocking', 'Pollenfeld_Gotzelshard',
#        'Polsingen_Dockingen', 'Pornbach_Puch', 'Pottmes_Schorn',
#        'Prien_Stock', 'Puch', 'Pullach_Hollriegelskreuth',
#        'Putzbrunn_Solalinden', 'Radolfzell_Markelfingen', 'Rain_am_Lech',
#        'Rain_am_Lech_Wallerdorf', 'Raisting', 'Ramsau_bei_Berchtesgaden',
#        'Rastatt', 'Raubling_Pfraundorf', 'Rauhod_bei_Schonstett',
#        'Rauschberg_bei_Ruhpolding', 'Regen', 'Regensburg_Burgweinting',
#        'Rehlingen', 'Reichenhall_Bad', 'Reichertsheim', 'Reimlingen',
#        'Reisbach_Haberskirchen', 'Reisbach_Oberhausen', 'Reischach',
#        'Reit_im_Winkl', 'Remseck_Neckar_Aldingen',
#        'Renningen_Ihinger_Hof', 'Rettenberg_Kranzegg',
#        'Reutlingen_Betzingen', 'Rheinau_Memprechtshofen',
#        'Rheinfelden_DE_DWD', 'Rheinstetten', 'Riedenburg', 'Riedering',
#        'Riedoschingen', 'Riekofen', 'Rielasingen', 'Rippoldsau_Bad',
#        'Rohrmoos_Grossinzemoos', 'Rohrnbach', 'Rohrnbach_Reisersberg',
#        'Rosenfeld_Bickelsberg', 'Rosenheim', 'Rosenheim_Flussbauamt_',
#        'Rot_an_der_Rot_Buch', 'Rot_an_der_Rot_Spindelwag',
#        'Rottenburg_Kiebingen', 'Rottenburg_Niederbayern_Oberroning',
#        'Rottenburg_Niederbayern_Pattendorf', 'Rottenburg_Niedernau_Bad',
#        'Rotthalmunster', 'Rottweil', 'Rudersberg', 'Ruderting',
#        'Ruhpolding', 'Ruhpolding_Seehaus', 'Rusel_Irlmoos', 'Rust_DE_DWD',
#        'Rutesheim', 'Sachsenheim', 'Sackingen_Bad_Bergseestr_',
#        'Saldenburg_Entschenreuth', 'Saldenburg_Stadl', 'Salgen',
#        'Sallneck', 'Samerberg_Geisenkam', 'Sankt_Blasien_Menzenschwand',
#        'Sankt_Georgen_Schwarzwald', 'Sankt_Johann_Gachingen',
#        'Sankt_Oswald_Riedlhutte', 'Sankt_Peter_Schwarzwald',
#        'Sauerlach_Altkirchen', 'Sauggart', 'Saulgau_Bad_Bolstern',
#        'Schaftlach', 'Schaftlarn_Kloster_Schaftlarn',
#        'Schallstadt_Mengen', 'Schauinsland', 'Schemmerhofen_Ingerkingen',
#        'Schemmerhofen_Schemmerberg', 'Scheuring', 'Scheyern',
#        'Schierling', 'Schiltach', 'Schleching', 'Schliersee',
#        'Schliersee_A_', 'Schnaitsee', 'Schneizlreuth_Ristfeucht',
#        'Schneizlreuth_Unterjettenberg', 'Schneizlreuth_Weissbach',
#        'Schofweg', 'Schollnach_Taiding', 'Schonau_Oberbayern_Durreck_',
#        'Schonau_Schwarzwald', 'Schonberg_Niederbayern', 'Schonmunzach',
#        'Schopfheim_Eichen', 'Schopfheim_Schweigmatt', 'Schramberg',
#        'Schrobenhausen', 'Schussenried_Bad_Olzreute', 'Schuttertal',
#        'Schuttertal_Schweighausen', 'Schwabbruck',
#        'Schwabisch_Gmund_Strassdorf', 'Schwabmunchen', 'Schwaigermoos',
#        'Schwanau_Ottenheim', 'Schwangau_Horn', 'Schwangau_Neuschwanstein',
#        'Schwarzbachwacht', 'Schweitenkirchen_Sunzhausen',
#        'Schwendi_Kleinschafhausen', 'Schwenningen_Kreis_Sigmaringen',
#        'Seefeld_Oberbayern_Unering', 'Seeg_Klaranlage_', 'Seelbach',
#        'Seeshaupt', 'Seewald_Besenfeld', 'Sersheim',
#        'Siegenburg_Klaranlage_', 'Siegsdorf', 'Siegsdorf_Maria_Eck',
#        'Sigmaringen_Laiz', 'Sigmarszell_Zeisertsweiler', 'Simbach_Inn',
#        'Simmersfeld', 'Simonswald_Obersimonswald', 'Sindelfingen',
#        'Sindelsdorf', 'Sinzheim_Leiberstung', 'Solnhofen', 'Sonnen',
#        'Sonnenbuhl_Genkingen', 'Sontheim',
#        'Sonthofen_Flussmeisterstelle_', 'Spiegelau_Klingenbrunn',
#        'Spraitbach', 'Stammham_Appertshofen', 'Starnberg', 'Stegen',
#        'Steinach', 'Steingaden_Lauterbach', 'Steingaden_Riesen',
#        'Steinhausen_Englisweiler', 'Steinkirchen_Hofstarring',
#        'Steinmauern', 'Stetten_Frohnstetten', 'Stiefenhofen', 'Stockach',
#        'Stotten', 'Strass_bei_Geratskirchen', 'Strasskirchen',
#        'Strasslach_Muhlthal', 'Straubenhardt_Schwann', 'Straubing',
#        'Straubing_Ittling', 'Stuhlingen_Eberfingen',
#        'Stuttgart_Echterdingen', 'Stuttgart_Hohenheim',
#        'Stuttgart_Neckartal_', 'Stuttgart_Rohr',
#        'Stuttgart_Schnarrenberg_', 'Stuttgart_Stadt',
#        'Stuttgart_Weilimdorf', 'Sudelfeld', 'Sudelfeld_Polizeiheim_',
#        'Syrgenstein_Altenberg', 'Tacherting_Altenham',
#        'Tacherting_Spreit', 'Tafertshofen', 'Tagmersheim_Blossenau',
#        'Talheim', 'Tatzelwurm', 'Taufkirchen_Vils_Baum', 'Teisendorf',
#        'Teisendorf_Neukirchen', 'Tettnang_Tannau', 'Thyrnau',
#        'Tiefenbach_Oberndorf', 'Tiefenbronn',
#        'Titisee_Neustadt_Langenordnach', 'Titting_Heiligenkreuz',
#        'Tittling', 'Tittmoning', 'Todtmoos', 'Todtnau',
#        'Todtnau_Aftersteg', 'Tolz_Bad', 'Traunreut_Fruhling',
#        'Traunstein_Axdorf', 'Treuchtlingen_Auernheim',
#        'Treuchtlingen_Schambach', 'Triberg_Nussbach', 'Triftern',
#        'Trochtelfingen_Wilsingen', 'Trostberg', 'Truchtlaching',
#        'Tubingen_Bebenhausen', 'Tubingen_Botanischer_Garten_',
#        'Tuntenhausen_Weiching', 'Turkheim', 'Tussling', 'Tuttlingen',
#        'Tuttlingen_Mohringen_Vorstadt', 'Tutzing_Oberzeismering',
#        'Tutzing_Traubing', 'Uberlingen_Bodensee', 'Ubersee_Feldwies',
#        'Uffing_am_Staffelsee_Schoffau', 'Uhlingen_Birkendorf', 'Ulm',
#        'Unterammergau', 'Unterfohring', 'Untergriesbach_Glotzing',
#        'Untergriesbach_Schaibing', 'Unterreit_Wagenstatt',
#        'Unterwossen_Hinterwossen', 'Untrasried_Maneberg',
#        'Uttenweiler_Ahlen', 'Utting_Achselschwang',
#        'Vaihingen_an_der_Enz_Riet', 'Valley_Muhlthal', 'Valley_Schmidham',
#        'Veringenstadt', 'Vilgertshofen_Pflugdorf',
#        'Villingen_Schwenningen', 'Villingen_Schwenningen_FTS_',
#        'Vilsbiburg', 'Vilsheim_Munchsdorf', 'Vilshofen_Schweiklberg_',
#        'Vogtareuth', 'Vogtsburg_Oberrotweil', 'Vohrenbach_Langenbach',
#        'Waakirchen_Demmelberg', 'Waging_am_See', 'Waiblingen',
#        'Waldau_Jostal', 'Waldhauser_National_Park_', 'Waldkirchen',
#        'Waldkirchen_Oberfrauenwald', 'Waldsee_Bad_Dinnenried', 'Waldshut',
#        'Waldstetten_Wissgoldingen', 'Wallerfing_Neusling', 'Wallersdorf',
#        'Wallgau_Obernach', 'Waltenhofen_Martinszell', 'Wang_Sporerau',
#        'Wangen_Allgau', 'Warngau_Taubenberg', 'Warthausen_Birkenhard',
#        'Wasserburg_Inn_Reisach', 'Watzmannhaus', 'Wechingen', 'Wegscheid',
#        'Weichs', 'Weihenstephan_Durnast',
#        'Weihenstephan_Landessaatzuchtanstalt', 'Weil_am_Rhein_Haltingen',
#        'Weil_der_Stadt', 'Weil_im_Schonbuch', 'Weilenbach',
#        'Weilheim_Oberbayern', 'Weilheim_Waldshut_Bannholz',
#        'Weingarten_Kr_Ravensburg', 'Weinstadt_Endersbach', 'Weisenbach',
#        'Weissach', 'Weissenburg_Rothenstein',
#        'Weissenhorn_Oberreichenbach', 'Weisweil_Waldeckhof',
#        'Weitnau_Wengen', 'Weizern_Hopferau', 'Welden', 'Wellendingen',
#        'Wellheim_Hard', 'Welzheim', 'Welzheim_A_', 'Wendelstein',
#        'Wertach_Bichel', 'Wertach_Buronhutte_', 'Wertingen', 'Wessobrunn',
#        'Westendorf_Kreis_Ostallgau', 'Westerheim', 'Wiederhofen',
#        'Wielenbach_Demollstr_', 'Wiesenbach_Oberwiesenbach',
#        'Wiessee_Bad_Bauer_in_der_Au', 'Wiggensbach_Schachen',
#        'Wildbad_Bad_Calmbach', 'Wildbad_Bad_Sommerberg', 'Wilhelmsdorf',
#        'Willerazhofen', 'Willstatt_Legelshurst', 'Wimsheim',
#        'Winhoring_Enhofen', 'Winterbach_Rems_Murr_Kreis', 'Wittibreut',
#        'Wolfach', 'Wolfegg_Neckenfurt_', 'Wolfratshausen', 'Wolfschlugen',
#        'Wolfstein_bei_Freyung', 'Wolnzach', 'Worishofen_Bad',
#        'Worth_Oberbayern_Horlkofen', 'Worth_Oberpfalz_Kiefenholz',
#        'Wurmannsquick_Egelsberg', 'Wurmsham_Pauluszell', 'Wurzach_Bad',
#        'Wutoschingen_Ofteringen', 'Zeilarn_Gumpersdorf',
#        'Zell_am_Harmersbach_Unterharmersbach',
#        'Zell_im_Wiesental_Pfaffenberg', 'Ziemetshausen',
#        'Ziemetshausen_Seifriedsberg', 'Zorneding', 'Zugspitze',
#        'Zusmarshausen', 'Zwiefalten'], dtype=object)

# %% [markdown]
# # Snow cover area over time for the 4 stations

# %%
snow_data_Bondorf = snow_data.where(snow_data.Name=='Bondorf').dropna()
snow_data_Oberammergau = snow_data.where(snow_data.Name=='Bondorf').dropna()
snow_data_Zugspitze = snow_data.where(snow_data.Name=='Bondorf').dropna()
snow_data_Hohenpreissenberg = snow_data.where(snow_data.Name=='Bondorf').dropna()
# Out:
#           Name    year  month  HNsum    HSmean  HSmax  SCD1  SCD1gt  SCD10  \
# 58872  Bondorf  1979.0    1.0   35.0  9.903226   22.0  29.0    29.0   14.0
# 58873  Bondorf  1979.0    2.0   15.0  4.928571   25.0  20.0    16.0    6.0
# 58874  Bondorf  1979.0    3.0    0.0  0.000000    0.0   0.0     0.0    0.0
# 58875  Bondorf  1979.0    4.0    0.0  0.000000    0.0   0.0     0.0    0.0
# 58876  Bondorf  1979.0    5.0    0.0  0.000000    0.0   0.0     0.0    0.0
# ...        ...     ...    ...    ...       ...    ...   ...     ...    ...
# 59131  Bondorf  2000.0    8.0    0.0  0.000000    0.0   0.0     0.0    0.0
# 59132  Bondorf  2000.0    9.0    0.0  0.000000    0.0   0.0     0.0    0.0
# 59133  Bondorf  2000.0   10.0    0.0  0.000000    0.0   0.0     0.0    0.0
# 59134  Bondorf  2000.0   11.0    0.0  0.000000    0.0   0.0     0.0    0.0
# 59135  Bondorf  2000.0   12.0    7.0  0.000000    0.0   0.0     0.0    0.0
#
#        SCD20  ...  HSmean_gapfill  frac_gapfilled  HSmax_gapfill  \
# 58872    3.0  ...        9.903226             0.0           22.0
# 58873    2.0  ...        4.928571             0.0           25.0
# 58874    0.0  ...        0.000000             0.0            0.0
# 58875    0.0  ...        0.000000             0.0            0.0
# 58876    0.0  ...        0.000000             0.0            0.0
# ...      ...  ...             ...             ...            ...
# 59131    0.0  ...        0.000000             0.0            0.0
# 59132    0.0  ...        0.000000             0.0            0.0
# 59133    0.0  ...        0.000000             0.0            0.0
# 59134    0.0  ...        0.000000             0.0            0.0
# 59135    0.0  ...        0.000000             0.0            0.0
#
#        SCD1_gapfill  SCD1gt_gapfill  SCD10_gapfill  SCD20_gapfill  \
# 58872          29.0            29.0           14.0            3.0
# 58873          20.0            16.0            6.0            2.0
# 58874           0.0             0.0            0.0            0.0
# 58875           0.0             0.0            0.0            0.0
# 58876           0.0             0.0            0.0            0.0
# ...             ...             ...            ...            ...
# 59131           0.0             0.0            0.0            0.0
# 59132           0.0             0.0            0.0            0.0
# 59133           0.0             0.0            0.0            0.0
# 59134           0.0             0.0            0.0            0.0
# 59135           0.0             0.0            0.0            0.0
#
#        SCD30_gapfill  SCD50_gapfill  SCD100_gapfill
# 58872            0.0            0.0             0.0
# 58873            0.0            0.0             0.0
# 58874            0.0            0.0             0.0
# 58875            0.0            0.0             0.0
# 58876            0.0            0.0             0.0
# ...              ...            ...             ...
# 59131            0.0            0.0             0.0
# 59132            0.0            0.0             0.0
# 59133            0.0            0.0             0.0
# 59134            0.0            0.0             0.0
# 59135            0.0            0.0             0.0
#
# [264 rows x 23 columns]
